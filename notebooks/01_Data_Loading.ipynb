# %% [markdown]
# # 01 - Data Loading
# Loading the Global Weather Repository dataset and profiling its structure.
#
# **Note:** This sandbox has no network access to kaggle.com, so `data/raw/GlobalWeatherRepository.csv` is a schema-matched synthetic stand-in generated by `scripts/generate_sample_dataset.py`. Drop the real Kaggle CSV in the same path to use actual data — every cell below is unchanged either way.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from src.data_loader import load_raw_data, profile_dataset, print_profile

df = load_raw_data()
df.head()
# Out:
# 2026-07-03 05:37:03 | src.data_loader | INFO | Loaded raw data: 12040 rows x 41 columns
# 2026-07-03 05:37:03 | src.data_loader | INFO | load_raw_data finished in 0.62s
#          country location_name  latitude  longitude          timezone  \
# 0  United States      New York     40.71     -74.01  America/New_York
# 1  United States      New York     40.71     -74.01  America/New_York
# 2  United States      New York     40.71     -74.01  America/New_York
# 3  United States      New York     40.71     -74.01  America/New_York
# 4  United States      New York     40.71     -74.01  America/New_York
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1717200000  2024-06-01 00:00                  1.4
# 1          1717286400  2024-06-02 00:00                  0.2
# 2          1717372800  2024-06-03 00:00                  0.8
# 3          1717459200  2024-06-04 00:00                 -0.7
# 4          1717545600  2024-06-05 00:00                  0.2
#
# ...

# %% [markdown]
# ## Shape, columns, and dtypes

# %%
print('Shape:', df.shape)
print('\nColumns:', list(df.columns))
# Out:
# Shape: (12040, 41)
#
# Columns: ['country', 'location_name', 'latitude', 'longitude', 'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius', 'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km', 'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide', 'air_quality_Ozone', 'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination']

# %%
df.dtypes
# Out:
# country                             str
# location_name                       str
# latitude                        float64
# longitude                       float64
# timezone                            str
# last_updated_epoch                int64
# last_updated                        str
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                      str
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                      str
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                        float64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %% [markdown]
# ## Summary statistics

# %%
df.describe(include='number').T
# Out:
#                                 count          mean           std  \
# latitude                      12040.0  2.416604e+01  2.930368e+01
# longitude                     12040.0  2.757479e+01  6.884034e+01
# last_updated_epoch            12040.0  1.725794e+09  4.988400e+06
# temperature_celsius           12040.0  1.083912e+01  1.176484e+01
# temperature_fahrenheit        12040.0  5.120642e+01  1.961741e+01
# wind_mph                      12040.0  7.452841e+00  5.285001e+00
# wind_kph                      11799.0  1.254726e+01  1.324228e+01
# wind_degree                   12040.0  1.792216e+02  1.037593e+02
# pressure_mb                   11799.0  1.012995e+03  6.010757e+00
# pressure_in                   12040.0  2.991375e+01  1.774824e-01
# precip_mm                     11798.0  2.596457e-01  8.313717e-01
# precip_in                     12040.0  1.023754e-02  3.276793e-02
# humidity                      11800.0  6.404059e+01  1.142770e+01
# ...

# %% [markdown]
# ## Memory usage, duplicates, missing values

# %%
print_profile(df)
# Out:
# ...
# DATASET OVERVIEW
# ...
# Shape               : 12,040 rows x 41 columns
# Memory usage        : 4.92 MB
# Duplicate rows      : 40
# Total missing cells : 1,687
#
# Column dtypes:
# float64    24
# str        11
# int64       6
# Name: count, dtype: int64
#
# Top 10 columns by missing values:
# precip_mm                 242
# uv_index                  242
# pressure_mb               241
# wind_kph                  241
# air_quality_PM2.5         241
# humidity                  240
# visibility_km             240
# location_name               0
# country                     0
# temperature_fahrenheit      0
# dtype: int64
#
# Numeric summary statistics:
#                                 count          mean         std           min  \
# latitude                      12040.0  2.417000e+01       29.30 -3.781000e+01
# longitude                     12040.0  2.757000e+01       68.84 -1.231200e+02
# last_updated_epoch            12040.0  1.725794e+09  4988400.33  1.717200e+09
# ...

# %% [markdown]
# ## Save profile for later phases

# %%
profile = profile_dataset(df)
print('Duplicate rows:', profile['duplicate_rows'])
print('Total missing cells:', sum(profile['missing_values'].values()))
# Out:
# Duplicate rows: 40
# Total missing cells: 1687
