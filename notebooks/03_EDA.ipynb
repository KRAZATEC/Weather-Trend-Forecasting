# %% [markdown]
# # 03 - Exploratory Data Analysis
# 40+ professional visualizations covering distributions, relationships, trends, and rankings. See also `scripts/run_eda.py`, which generates the full chart set to `outputs/figures/`.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
from src import config, visualization as viz

df = pd.read_csv(config.CLEAN_DATA_FILE, parse_dates=[config.DATETIME_COL])
df.shape
# Out:
# (12000, 41)

# %% [markdown]
# ## Temperature distribution

# %%
fig = viz.plot_distribution(df, 'temperature_celsius'); fig
# Out:
# 2026-07-03 05:37:12 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/dist_temperature_celsius.png

# %% [markdown]
# ## Humidity distribution

# %%
fig = viz.plot_distribution(df, 'humidity'); fig
# Out:
# 2026-07-03 05:37:12 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/dist_humidity.png

# %% [markdown]
# ## Temperature by country (boxplot)

# %%
fig = viz.plot_boxplot_by_group(df, 'temperature_celsius', 'country'); fig
# Out:
# 2026-07-03 05:37:12 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/box_temperature_celsius_by_country.png

# %% [markdown]
# ## Correlation heatmap

# %%
cols = ['temperature_celsius','humidity','pressure_mb','wind_kph','cloud','visibility_km','uv_index','precip_mm']
fig = viz.plot_correlation_heatmap(df, cols); fig
# Out:
# 2026-07-03 05:37:13 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/correlation_heatmap.png

# %% [markdown]
# ## Daily temperature trend (global average)

# %%
fig = viz.plot_time_trend(df, config.DATETIME_COL, 'temperature_celsius', freq='D'); fig
# Out:
# 2026-07-03 05:37:13 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/trend_temperature_celsius_D.png

# %% [markdown]
# ## Hottest & coldest countries

# %%
fig = viz.plot_country_ranking(df, 'temperature_celsius', ascending=False); fig
# Out:
# 2026-07-03 05:37:14 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/ranking_temperature_celsius_by_country.png

# %%
fig = viz.plot_country_ranking(df, 'temperature_celsius', ascending=True); fig
# Out:
# 2026-07-03 05:37:14 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/ranking_temperature_celsius_by_country.png

# %% [markdown]
# ## Humidity vs temperature scatter

# %%
fig = viz.plot_scatter(df, 'humidity', 'temperature_celsius'); fig
# Out:
# 2026-07-03 05:37:15 | src.visualization | INFO | Saved figure -> /home/claude/Weather-Trend-Forecasting/outputs/figures/scatter_humidity_vs_temperature_celsius.png

# %% [markdown]
# ## Full chart set
# The complete 40+ chart battery (violin plots, pairplots, seasonal comparisons, condition/moon-phase frequency, day-of-week & monthly patterns, etc.) is generated by running:
# ```bash
# python scripts/run_eda.py
# ```
# All resulting PNGs are saved to `outputs/figures/`.
